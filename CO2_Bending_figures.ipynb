# %%
import csv
from matplotlib import pyplot as plt

# Parse standard ASM data
CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
AlH3_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
BH3_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
NMe3_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', []), ('strain_frag2', []), ('interaction_frag2', []), ('energy_frag2', [])])
PMe3_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', []), ('strain_frag2', []), ('interaction_frag2', []), ('energy_frag2', [])])
NCAl_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
NCB_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
PCAl_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
PCB_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
NMe2Al_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
NMe2B_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
PMe2Al_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])
PMe2B_CO2 = dict([('BH_bond', []), ('OCO_angle', []), ('strain', []), ('interaction', []), ('energy', [])])

colors = dict()
colors['CO2'] = "#293133"
colors['BH3_CO2'] = "#059640"
colors['AlH3_CO2'] = "#de1513"
colors['NMe3_CO2'] = "#edb908"
colors['PMe3_CO2'] = "#0408e0"
colors['NCB_CO2'] = "#8aa80a"
colors['NCAl_CO2'] = "#b24903"
colors['PCB_CO2'] = "#008ea6"
colors['PCAl_CO2'] = "#7811a3"
colors['NMe2B_CO2'] = "#8aa80a"
colors['NMe2Al_CO2'] = "#b24903"
colors['PMe2B_CO2'] = "#008ea6"
colors['PMe2Al_CO2'] = "#7811a3"

with open('data/NBO_extract_g16_wB97XDDef2TZVP.csv', 'r') as data_file:
    plots = csv.reader(data_file, delimiter=';')
    next(plots)
    next(plots)
    for row in plots:
        # Free CO2
        CO2['BH_bond'].append(row[0])
        CO2['OCO_angle'].append(row[1])
        CO2['strain'].append(row[2])
        CO2['interaction'].append(row[3])
        CO2['energy'].append(row[4])
        # BH3 Adduct
        BH3_CO2['BH_bond'].append(row[10])
        BH3_CO2['OCO_angle'].append(row[11])
        BH3_CO2['strain'].append(row[12])
        BH3_CO2['interaction'].append(row[13])
        BH3_CO2['energy'].append(row[14])
        # AlH3 adduct
        AlH3_CO2['BH_bond'].append(row[20])
        AlH3_CO2['OCO_angle'].append(row[21])
        AlH3_CO2['strain'].append(row[22])
        AlH3_CO2['interaction'].append(row[23])
        AlH3_CO2['energy'].append(row[24])
        # NMe3 adduct
        NMe3_CO2['BH_bond'].append(row[30])
        NMe3_CO2['OCO_angle'].append(row[31])
        NMe3_CO2['strain'].append(row[32])
        NMe3_CO2['interaction'].append(row[33])
        NMe3_CO2['energy'].append(row[34])
        NMe3_CO2['strain_frag2'].append(row[35])
        NMe3_CO2['interaction_frag2'].append(row[36])
        NMe3_CO2['energy_frag2'].append(row[37])
        # PMe3 adduct
        PMe3_CO2['BH_bond'].append(row[40])
        PMe3_CO2['OCO_angle'].append(row[41])
        PMe3_CO2['strain'].append(row[42])
        PMe3_CO2['interaction'].append(row[43])
        PMe3_CO2['energy'].append(row[44])
        PMe3_CO2['strain_frag2'].append(row[45])
        PMe3_CO2['interaction_frag2'].append(row[46])
        PMe3_CO2['energy_frag2'].append(row[47])
        # NCB adduct
        NCB_CO2['BH_bond'].append(row[50])
        NCB_CO2['OCO_angle'].append(row[51])
        NCB_CO2['strain'].append(row[52])
        NCB_CO2['interaction'].append(row[53])
        NCB_CO2['energy'].append(row[54])
        # NCAl adduct
        NCAl_CO2['BH_bond'].append(row[60])
        NCAl_CO2['OCO_angle'].append(row[61])
        NCAl_CO2['strain'].append(row[62])
        NCAl_CO2['interaction'].append(row[63])
        NCAl_CO2['energy'].append(row[64])
        # PCB adduct
        PCB_CO2['BH_bond'].append(row[70])
        PCB_CO2['OCO_angle'].append(row[71])
        PCB_CO2['strain'].append(row[72])
        PCB_CO2['interaction'].append(row[73])
        PCB_CO2['energy'].append(row[74])
        # PCAl adduct
        PCAl_CO2['BH_bond'].append(row[80])
        PCAl_CO2['OCO_angle'].append(row[81])
        PCAl_CO2['strain'].append(row[82])
        PCAl_CO2['interaction'].append(row[83])
        PCAl_CO2['energy'].append(row[84])
        # NMe2B adduct
        NMe2B_CO2['BH_bond'].append(row[90])
        NMe2B_CO2['OCO_angle'].append(row[91])
        NMe2B_CO2['strain'].append(row[92])
        NMe2B_CO2['interaction'].append(row[93])
        NMe2B_CO2['energy'].append(row[94])
        # NMe2Al adduct
        NMe2Al_CO2['BH_bond'].append(row[100])
        NMe2Al_CO2['OCO_angle'].append(row[101])
        NMe2Al_CO2['strain'].append(row[102])
        NMe2Al_CO2['interaction'].append(row[103])
        NMe2Al_CO2['energy'].append(row[104])
        # PMe2B adduct
        PMe2B_CO2['BH_bond'].append(row[110])
        PMe2B_CO2['OCO_angle'].append(row[111])
        PMe2B_CO2['strain'].append(row[112])
        PMe2B_CO2['interaction'].append(row[113])
        PMe2B_CO2['energy'].append(row[114])
        # PMe2Al adduct
        PMe2Al_CO2['BH_bond'].append(row[120])
        PMe2Al_CO2['OCO_angle'].append(row[121])
        PMe2Al_CO2['strain'].append(row[122])
        PMe2Al_CO2['interaction'].append(row[123])
        PMe2Al_CO2['energy'].append(row[124])
# # Parse additional ASM Data
# # Add fields for the additional data in useful dictionaries
# CO2.update([('frag_CO2', []), ('frag_BH3', []), ('Pauli', []), ('Elstat', []), ('Steric', []), ('OI', [])])
# NCAl_CO2.update([('frag_CO2', []), ('frag_BH3', []), ('Pauli', []), ('Elstat', []), ('Steric', []), ('OI', [])])
# # Actually do the parsing
# with open('data/ASM-extended-data.txt', 'r') as data_file:
#     plots = csv.reader(data_file, delimiter='\t')
#     next(plots)
#     next(plots)
#     for row in plots:
#         # Free CO2
#         CO2['frag_CO2'].append(row[3])
#         CO2['frag_BH3'].append(row[2])
#         CO2['Steric'].append(row[6])
#         CO2['OI'].append(row[7])
#         # NCAl
#         NCAl_CO2['frag_CO2'].append(row[63])
#         NCAl_CO2['frag_BH3'].append(row[62])
#         NCAl_CO2['Steric'].append(row[66])
#         NCAl_CO2['OI'].append(row[67])

# For all dicts, remove blank values that were parsed
CO2 = {j:[float(i) for i in CO2[j] if i] for j in CO2}
AlH3_CO2 = {j:[float(i) for i in AlH3_CO2[j] if i] for j in AlH3_CO2}
BH3_CO2 = {j:[float(i) for i in BH3_CO2[j] if i] for j in BH3_CO2}
NMe3_CO2 = {j:[float(i) for i in NMe3_CO2[j] if i] for j in NMe3_CO2}
PMe3_CO2 = {j:[float(i) for i in PMe3_CO2[j] if i] for j in PMe3_CO2}
NCB_CO2 = {j:[float(i) for i in NCB_CO2[j] if i] for j in NCB_CO2}
NCAl_CO2 = {j:[float(i) for i in NCAl_CO2[j] if i] for j in NCAl_CO2}
PCB_CO2 = {j:[float(i) for i in PCB_CO2[j] if i] for j in PCB_CO2}
PCAl_CO2 = {j:[float(i) for i in PCAl_CO2[j] if i] for j in PCAl_CO2}
NMe2B_CO2 = {j:[float(i) for i in NMe2B_CO2[j] if i] for j in NMe2B_CO2}
NMe2Al_CO2 = {j:[float(i) for i in NMe2Al_CO2[j] if i] for j in NMe2Al_CO2}
PMe2B_CO2 = {j:[float(i) for i in PMe2B_CO2[j] if i] for j in PMe2B_CO2}
PMe2Al_CO2 = {j:[float(i) for i in PMe2Al_CO2[j] if i] for j in PMe2Al_CO2}

CO2.update({'TS_energy':11.1, 'TS_angle':153.4, 'TS_bond':1.281})
BH3_CO2.update({'TS_energy':10.3, 'TS_angle':156.3, 'TS_bond':1.261})
AlH3_CO2.update({'TS_energy':9.9, 'TS_angle':157.9, 'TS_bond':1.249})
NMe3_CO2.update({'TS_energy':8.1, 'TS_angle':151.7, 'TS_bond':1.283})
PMe3_CO2.update({'TS_energy':12.1, 'TS_angle':122.5, 'TS_bond':1.603})
PCB_CO2.update({'TS_energy':-2.2, 'TS_angle':124.1, 'TS_bond':1.326})
PCAl_CO2.update({'TS_energy':-3.5, 'TS_angle':124.7, 'TS_bond':1.308})
NCB_CO2.update({'TS_energy':-1.8, 'TS_angle':128.5, 'TS_bond':1.286})
NCAl_CO2.update({'TS_energy':-3.4, 'TS_angle':127.8, 'TS_bond':1.289})
PMe2B_CO2.update({'TS_energy':-4.5, 'TS_angle':122.9, 'TS_bond':1.321})
PMe2Al_CO2.update({'TS_energy':-5.3, 'TS_angle':123.5, 'TS_bond':1.304})
NMe2B_CO2.update({'TS_energy':0.9, 'TS_angle':126.2, 'TS_bond':1.278})
NMe2Al_CO2.update({'TS_energy':-2.2, 'TS_angle':126.6, 'TS_bond':1.282})

# Parse NBO related data
NBO_CO2 = dict([('BH_bond', []), ('CO2_angle', []), ('C', []), ('H', []), ('B', []), ('O', [])])
NBO_AlH3 = dict([('BH_bond', []), ('CO2_angle', []), ('C', []), ('H', []), ('B', []), ('O', [])])
NBO_Me3N = dict([('BH_bond', []), ('CO2_angle', []), ('C', []), ('H', []), ('B', []), ('O', [])])
NBO_NCAl = dict([('BH_bond', []), ('CO2_angle', []), ('C', []), ('H', []), ('B', []), ('O', [])])

with open('data/NBO-CO2.data', 'r') as data_file:
    plots = csv.reader(data_file, delimiter='\t')
    next(plots)
    for row in plots:
        NBO_CO2['BH_bond'].append(row[1])
        NBO_CO2['CO2_angle'].append(row[2])
        NBO_CO2['C'].append(row[3])
        NBO_CO2['O'].append(row[5])
        NBO_CO2['H'].append(row[6])
        NBO_CO2['B'].append(row[7])

with open('data/NBO-AlH3.data', 'r') as data_file:
    plots = csv.reader(data_file, delimiter='\t')
    next(plots)
    for row in plots:
        NBO_AlH3['BH_bond'].append(row[1])
        NBO_AlH3['CO2_angle'].append(row[2])
        NBO_AlH3['C'].append(row[3])
        NBO_AlH3['O'].append(row[5])
        NBO_AlH3['H'].append(row[6])
        NBO_AlH3['B'].append(row[7])

with open('data/NBO-Me3N.data', 'r') as data_file:
    plots = csv.reader(data_file, delimiter='\t')
    next(plots)
    for row in plots:
        NBO_Me3N['BH_bond'].append(row[1])
        NBO_Me3N['CO2_angle'].append(row[2])
        NBO_Me3N['C'].append(row[3])
        NBO_Me3N['O'].append(row[5])
        NBO_Me3N['H'].append(row[6])
        NBO_Me3N['B'].append(row[7])

with open('data/NBO-NCAl.data', 'r') as data_file:
    plots = csv.reader(data_file, delimiter='\t')
    next(plots)
    for row in plots:
        NBO_NCAl['BH_bond'].append(row[1])
        NBO_NCAl['CO2_angle'].append(row[2])
        NBO_NCAl['C'].append(row[3])
        NBO_NCAl['O'].append(row[5])
        NBO_NCAl['H'].append(row[6])
        NBO_NCAl['B'].append(row[7])

NBO_CO2 = {j:[float(i) for i in NBO_CO2[j] if i] for j in NBO_CO2}
NBO_AlH3 = {j:[float(i) for i in NBO_AlH3[j] if i] for j in NBO_AlH3}
NBO_Me3N = {j:[float(i) for i in NBO_Me3N[j] if i] for j in NBO_Me3N}
NBO_NCAl = {j:[float(i) for i in NBO_NCAl[j] if i] for j in NBO_NCAl}

print("All data extracted!")

# %%
# CO2 ASM vs O-C-O angle
axis = plt.gca()
axis.set(xlim=(125, 180), ylim =(-80, 80))
axis.invert_xaxis()
plt.xlabel("$O-C-O$ Angle (°)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")

plt.plot(CO2['OCO_angle'], CO2['strain'], "#00008B", label="$CO_{2}$ Strain")
plt.plot(CO2['OCO_angle'], CO2['energy'], colors['CO2'], label="$CO_{2}$ Energy")
plt.plot(CO2['OCO_angle'], CO2['interaction'], "#880000", label="$CO_{2}$ Interaction")

plt.plot(CO2['TS_angle'], CO2['TS_energy'], "ok")
plt.plot((CO2['TS_angle'], CO2['TS_angle']), (-40, 55), colors['CO2'], linestyle='-.', linewidth='1')

# plt.legend(fontsize='small')
plt.savefig("data/CO2_OCOangle.png", dpi=300)

# %%
# All Energies
axis = plt.gca()
axis.set(xlim=(110, 180), ylim =(-10, 15))
axis.invert_xaxis()
plt.xlabel("$O-C-O$ Angle ($°$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
plt.plot(CO2['OCO_angle'], CO2['energy'], colors['CO2'], label="$CO_{2}$")
plt.plot(BH3_CO2['OCO_angle'], BH3_CO2['energy'], colors['BH3_CO2'], label="$BH_3$")
plt.plot(AlH3_CO2['OCO_angle'], AlH3_CO2['energy'], colors['AlH3_CO2'], label="$AlH_3$")
plt.plot(NMe3_CO2['OCO_angle'], NMe3_CO2['energy'], colors['NMe3_CO2'], label="$NMe_3$")
plt.plot(PMe3_CO2['OCO_angle'], PMe3_CO2['energy'], colors['PMe3_CO2'], label="$PMe_3$")
plt.plot(NMe2B_CO2['OCO_angle'], NMe2B_CO2['energy'], colors['NMe2B_CO2'], label="$NMe2B$")
plt.plot(NMe2Al_CO2['OCO_angle'], NMe2Al_CO2['energy'], colors['NMe2Al_CO2'], label="$NMe2Al$")
plt.plot(PMe2B_CO2['OCO_angle'], PMe2B_CO2['energy'], colors['PMe2B_CO2'], label="$NMe2B$")
plt.plot(PMe2Al_CO2['OCO_angle'], PMe2Al_CO2['energy'], colors['PMe2Al_CO2'], label="$NMe2Al$")

plt.plot(CO2['TS_angle'], CO2['TS_energy'], "ok")
plt.plot(BH3_CO2['TS_angle'], BH3_CO2['TS_energy'], "ok")
plt.plot(AlH3_CO2['TS_angle'], AlH3_CO2['TS_energy'], "ok")
plt.plot(NMe3_CO2['TS_angle'], NMe3_CO2['TS_energy'], "ok")
plt.plot(PMe3_CO2['TS_angle'], PMe3_CO2['TS_energy'], "ok")
plt.plot(NMe2B_CO2['TS_angle'], NMe2B_CO2['TS_energy'], "ok")
plt.plot(NMe2Al_CO2['TS_angle'], NMe2Al_CO2['TS_energy'], "ok")
plt.plot(PMe2B_CO2['TS_angle'], PMe2B_CO2['TS_energy'], "ok")
plt.plot(PMe2Al_CO2['TS_angle'], PMe2Al_CO2['TS_energy'], "ok")

# plt.legend(fontsize='small', ncol=2, loc='lower left')
plt.savefig("data/Energies_OCOAngle.png", dpi=300)

# %%
# All Energies
axis = plt.gca()
axis.set(xlim=(1.200, 2.200), ylim =(-10, 20))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
plt.plot(CO2['BH_bond'], CO2['energy'], colors['CO2'], label="$CO_{2}$")
plt.plot(BH3_CO2['BH_bond'], BH3_CO2['energy'], colors['BH3_CO2'], label="$BH_3$")
plt.plot(AlH3_CO2['BH_bond'], AlH3_CO2['energy'], colors['AlH3_CO2'], label="$AlH_3$")
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['energy'], colors['NMe3_CO2'], label="$NMe_3$")
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['energy'], colors['PMe3_CO2'], label="$PMe_3$")
plt.plot(NMe2B_CO2['BH_bond'], NMe2B_CO2['energy'], colors['NMe2B_CO2'], label="$NMe2B$")
plt.plot(NMe2Al_CO2['BH_bond'], NMe2Al_CO2['energy'], colors['NMe2Al_CO2'], label="$NMe2Al$")
plt.plot(PMe2B_CO2['BH_bond'], PMe2B_CO2['energy'], colors['PMe2B_CO2'], label="$PMe2B$")
plt.plot(PMe2Al_CO2['BH_bond'], PMe2Al_CO2['energy'], colors['PMe2Al_CO2'], label="$PMe2Al$")

plt.plot(CO2['TS_bond'], CO2['TS_energy'], "ok")
plt.plot(BH3_CO2['TS_bond'], BH3_CO2['TS_energy'], "ok")
plt.plot(AlH3_CO2['TS_bond'], AlH3_CO2['TS_energy'], "ok")
plt.plot(NMe3_CO2['TS_bond'], NMe3_CO2['TS_energy'], "ok")
plt.plot(PMe3_CO2['TS_bond'], PMe3_CO2['TS_energy'], "ok")
plt.plot(NMe2B_CO2['TS_bond'], NMe2B_CO2['TS_energy'], "ok")
plt.plot(NMe2Al_CO2['TS_bond'], NMe2Al_CO2['TS_energy'], "ok")
plt.plot(PMe2B_CO2['TS_bond'], PMe2B_CO2['TS_energy'], "ok")
plt.plot(PMe2Al_CO2['TS_bond'], PMe2Al_CO2['TS_energy'], "ok")

plt.legend(fontsize='small', ncol=2)
plt.savefig("data/Energies_BHBond.png", dpi=300)

# %%
# Lewis acids vs O-C-O angle
axis = plt.gca()
axis.set(xlim=(135, 180), ylim =(-60, 60))
axis.invert_xaxis()
plt.xlabel("$O-C-O$ Angle ($°$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
#
plt.plot(CO2['OCO_angle'], CO2['strain'], colors['CO2'], label="$CO_{2}$")
plt.plot(CO2['OCO_angle'], CO2['interaction'], colors['CO2'])
plt.plot(CO2['OCO_angle'], CO2['energy'], colors['CO2'])
plt.plot(BH3_CO2['OCO_angle'], BH3_CO2['strain'], colors['BH3_CO2'], label="$BH_3-CO_{2}$")
plt.plot(BH3_CO2['OCO_angle'], BH3_CO2['interaction'], colors['BH3_CO2'])
plt.plot(BH3_CO2['OCO_angle'], BH3_CO2['energy'], colors['BH3_CO2'])
plt.plot(AlH3_CO2['OCO_angle'], AlH3_CO2['strain'], colors['AlH3_CO2'], label="$AlH_3-CO_{2}$")
plt.plot(AlH3_CO2['OCO_angle'], AlH3_CO2['interaction'], colors['AlH3_CO2'])
plt.plot(AlH3_CO2['OCO_angle'], AlH3_CO2['energy'], colors['AlH3_CO2'])
plt.plot(CO2['TS_angle'], CO2['TS_energy'], "ok")
plt.plot(BH3_CO2['TS_angle'], BH3_CO2['TS_energy'], "ok")
plt.plot(AlH3_CO2['TS_angle'], AlH3_CO2['TS_energy'], "ok")

#plt.legend(fontsize='small')
plt.savefig("data/LewisAcid_OCOAngle.png", dpi=300)

# %%
# Lewis acids vs B-H bond
axis = plt.gca()
axis.set(xlim=(1.19, 1.43), ylim =(-60, 60))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
# 
plt.plot(CO2['BH_bond'], CO2['strain'], colors['CO2'], label="$CO_{2}$")
plt.plot(CO2['BH_bond'], CO2['interaction'], colors['CO2'])
plt.plot(CO2['BH_bond'], CO2['energy'], colors['CO2'])
plt.plot(BH3_CO2['BH_bond'], BH3_CO2['strain'], colors['BH3_CO2'], label="$BH_3-CO_{2}$")
plt.plot(BH3_CO2['BH_bond'], BH3_CO2['interaction'], colors['BH3_CO2'])
plt.plot(BH3_CO2['BH_bond'], BH3_CO2['energy'], colors['BH3_CO2'])
plt.plot(AlH3_CO2['BH_bond'], AlH3_CO2['strain'], colors['AlH3_CO2'], label="$AlH_3-CO_{2}$")
plt.plot(AlH3_CO2['BH_bond'], AlH3_CO2['interaction'], colors['AlH3_CO2'])
plt.plot(AlH3_CO2['BH_bond'], AlH3_CO2['energy'], colors['AlH3_CO2'])
plt.plot(CO2['TS_bond'], CO2['TS_energy'], "ok")
plt.plot(BH3_CO2['TS_bond'], BH3_CO2['TS_energy'], "ok")
plt.plot(AlH3_CO2['TS_bond'], AlH3_CO2['TS_energy'], "ok")

#plt.legend(fontsize='small')
plt.savefig("data/LewisAcid_BHBond.png", dpi=300)

# %%
# Lewis bases vs BH bond
axis = plt.gca()
axis.set(xlim=(1.19, 1.80), ylim =(-100, 100))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
#
plt.plot(CO2['BH_bond'], CO2['strain'], colors['CO2'], label="$CO_{2}$")
plt.plot(CO2['BH_bond'], CO2['interaction'], colors['CO2'])
plt.plot(CO2['BH_bond'], CO2['energy'], colors['CO2'])
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['strain'], colors['NMe3_CO2'], label="$NMe_3-CO_{2}$")
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['interaction'], colors['NMe3_CO2'])
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['energy'], colors['NMe3_CO2'])
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['strain'], colors['PMe3_CO2'], label="$PMe_3-CO_{2}$")
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['interaction'], colors['PMe3_CO2'])
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['energy'], colors['PMe3_CO2'])
plt.plot(CO2['TS_bond'], CO2['TS_energy'], "ok")
plt.plot(NMe3_CO2['TS_bond'], NMe3_CO2['TS_energy'], "ok")
plt.plot(PMe3_CO2['TS_bond'], PMe3_CO2['TS_energy'], "ok")

plt.legend(fontsize='small')
plt.savefig("data/LewisBase_BHBond.png", dpi=300)

# %%
# Lewis bases vs BH bond - 2nd fragmentation
axis = plt.gca()
axis.set(xlim=(1.18, 2.10), ylim =(-100, 100))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
#
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['strain_frag2'], colors['NMe3_CO2'], label="$NMe_3-CO_{2}$")
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['interaction_frag2'], colors['NMe3_CO2'])
plt.plot(NMe3_CO2['BH_bond'], NMe3_CO2['energy_frag2'], colors['NMe3_CO2'])
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['strain_frag2'], colors['PMe3_CO2'], label="$PMe_3-CO_{2}$")
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['interaction_frag2'], colors['PMe3_CO2'])
plt.plot(PMe3_CO2['BH_bond'], PMe3_CO2['energy_frag2'], colors['PMe3_CO2'])
plt.plot(NMe3_CO2['TS_bond'], NMe3_CO2['TS_energy'], "ok")
plt.plot(PMe3_CO2['TS_bond'], PMe3_CO2['TS_energy'], "ok")

plt.legend(fontsize='small')
plt.savefig("data/LewisBase_BHBond-2ndFragmentation.png", dpi=300)

# %%
# FLP Energies
axis = plt.gca()
axis.set(xlim=(115, 135), ylim =(-10, 5))
axis.invert_xaxis()
plt.xlabel("$O-C-O$ Angle ($°$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")
plt.plot(NMe2B_CO2['OCO_angle'], NMe2B_CO2['energy'], colors['NMe2B_CO2'], label="$NMe2B$")
plt.plot(NMe2Al_CO2['OCO_angle'], NMe2Al_CO2['energy'], colors['NMe2Al_CO2'], label="$NMe2Al$")
plt.plot(PMe2B_CO2['OCO_angle'], PMe2B_CO2['energy'], colors['PMe2B_CO2'], label="$PMe2B$")
plt.plot(PMe2Al_CO2['OCO_angle'], PMe2Al_CO2['energy'], colors['PMe2Al_CO2'], label="$PMe2Al$")

plt.plot(NMe2B_CO2['TS_angle'], NMe2B_CO2['TS_energy'], "ok")
plt.plot(NMe2Al_CO2['TS_angle'], NMe2Al_CO2['TS_energy'], "ok")
plt.plot(PMe2B_CO2['TS_angle'], PMe2B_CO2['TS_energy'], "ok")
plt.plot(PMe2Al_CO2['TS_angle'], PMe2Al_CO2['TS_energy'], "ok")

plt.legend(fontsize='small')
plt.savefig("data/FLP_Energies_OCOAngle.png", dpi=300)

# %%
# CO2/NCAl vs BH Bond
axis = plt.gca()
axis.set(xlim=(1.19, 1.80), ylim =(-100, 100))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")

plt.plot(CO2['BH_bond'], CO2['strain'], colors['CO2'], label="$CO_{2}$")
plt.plot(CO2['BH_bond'], CO2['interaction'], colors['CO2'])
plt.plot(CO2['BH_bond'], CO2['energy'], colors['CO2'])
plt.plot(NMe2Al_CO2['BH_bond'][0:], NMe2Al_CO2['strain'][0:], colors['NMe2Al_CO2'], label="$NMe2Al-CO_{2}$")
plt.plot(NMe2Al_CO2['BH_bond'][0:], NMe2Al_CO2['interaction'][0:], colors['NMe2Al_CO2'])
plt.plot(NMe2Al_CO2['BH_bond'][0:], NMe2Al_CO2['energy'][0:], colors['NMe2Al_CO2'])

plt.plot(CO2['TS_bond'], CO2['TS_energy'], "ok")
plt.plot(NMe2Al_CO2['TS_bond'], NMe2Al_CO2['TS_energy'], "ok")

# plt.legend(fontsize='small')
plt.savefig("data/NMe2Al_BHbond.png", dpi=300)

# %%
# CO2/PMe2Al vs BH Bond
axis = plt.gca()
axis.set(xlim=(1.19, 1.80), ylim =(-100, 100))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("Energy ($kcal.mol^{-1}$)")

plt.plot(CO2['BH_bond'], CO2['strain'], colors['CO2'], label="$CO_{2}$")
plt.plot(CO2['BH_bond'], CO2['interaction'], colors['CO2'])
plt.plot(CO2['BH_bond'], CO2['energy'], colors['CO2'])
plt.plot(PMe2Al_CO2['BH_bond'][0:], PMe2Al_CO2['strain'][0:], colors['PMe2Al_CO2'], label="$NMe2Al-CO_{2}$")
plt.plot(PMe2Al_CO2['BH_bond'][0:], PMe2Al_CO2['interaction'][0:], colors['PMe2Al_CO2'])
plt.plot(PMe2Al_CO2['BH_bond'][0:], PMe2Al_CO2['energy'][0:], colors['PMe2Al_CO2'])

plt.plot(CO2['TS_bond'], CO2['TS_energy'], "ok")
plt.plot(PMe2Al_CO2['TS_bond'], PMe2Al_CO2['TS_energy'], "ok")

# plt.legend(fontsize='small')
plt.savefig("data/PMe2Al_BHbond.png", dpi=300)

# %%
# # CO2/NCAl Strain Analysis Decomposition
# axis = plt.gca()
# axis.set(xlim=(1.2, 1.60), ylim =(0, 50))
# plt.xlabel("$B-H$ Bond ($Å$)")
# plt.ylabel("Energy ($kcal.mol^{-1}$)")
#
# plt.plot(CO2['BH_bond'], CO2['frag_CO2'], colors['CO2'], label="$CO_{2}$")
# plt.plot(CO2['BH_bond'], CO2['frag_BH3'], colors['CO2'])
# plt.plot(NCAl_CO2['BH_bond'][280:], NCAl_CO2['frag_CO2'][280:], colors['NCAl_CO2'], label="$NCAl-CO_{2}$")
# plt.plot(NCAl_CO2['BH_bond'][280:], NCAl_CO2['frag_BH3'][280:], colors['NCAl_CO2'])
#
# plt.plot((CO2['TS_bond'], CO2['TS_bond']), (7, 28), colors['CO2'], linestyle='-.', linewidth='1')
# plt.plot((NCAl_CO2['TS_bond'], NCAl_CO2['TS_bond']), (7, 28), colors['NCAl_CO2'], linestyle='-.', linewidth='1')
#
# plt.savefig("data/NCAl_StrainComparison.png", dpi=300)

# %%
# # CO2/NCAl Interaction Decomposition
# axis = plt.gca()
# axis.set(xlim=(1.2, 1.55), ylim =(-300, 300))
# plt.xlabel("$B-H$ Bond ($Å$)")
# plt.ylabel("Energy ($kcal.mol^{-1}$)")
#
# plt.plot(CO2['BH_bond'], CO2['interaction'], colors['CO2'], label="$CO_{2}$")
# plt.plot(CO2['BH_bond'], CO2['Steric'], colors['CO2'])
# plt.plot(CO2['BH_bond'], CO2['OI'], colors['CO2'])
# plt.plot(NCAl_CO2['BH_bond'][280:], NCAl_CO2['interaction'][280:], colors['NCAl_CO2'], label="$NCAl-CO_{2}$")
# plt.plot(NCAl_CO2['BH_bond'][280:], NCAl_CO2['Steric'][280:], colors['NCAl_CO2'])
# plt.plot(NCAl_CO2['BH_bond'][280:], NCAl_CO2['OI'][280:], colors['NCAl_CO2'])
#
# plt.plot((CO2['TS_bond'], CO2['TS_bond']), (-200, 175), colors['CO2'], linestyle='-.', linewidth='1')
# plt.plot((NCAl_CO2['TS_bond'], NCAl_CO2['TS_bond']), (-200, 175), colors['NCAl_CO2'], linestyle='-.', linewidth='1')
#
# plt.savefig("data/NCAl_InteractionComparison.png", dpi=300)

# %%
# NBO charge comparison on C Atom
axis = plt.gca()
axis.set(xlim=(1.2, 1.50), ylim =(0.5, 1.2))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("NBO charge transfer on C")

plt.plot(NBO_CO2['BH_bond'], NBO_CO2['C'], colors['CO2'], label="$Free$ $CO_{2}$")
plt.plot(NBO_AlH3['BH_bond'], NBO_AlH3['C'], colors['AlH3_CO2'], label="$LA = AlH_{3}$")
plt.plot(NBO_Me3N['BH_bond'], NBO_Me3N['C'], colors['NMe3_CO2'], label="$LB = Me_{3}N$")
plt.plot(NBO_NCAl['BH_bond'], NBO_NCAl['C'], colors['NCAl_CO2'], label="$FLP = N/Al$")

plt.plot(CO2['TS_bond'], 0.955, "+k", label="$Transition$ $State$") # CO2
plt.plot(AlH3_CO2['TS_bond'], 1.046, "+k") # AlH3
plt.plot(NMe3_CO2['TS_bond'], 0.973, "+k") # NMe3
plt.plot(NCAl_CO2['TS_bond'], 0.860, "+k") # NCAl

plt.legend(fontsize='small')
plt.savefig("data/NBO_C.png", dpi=300)

# %%
# NBO charge comparison on O Atom
axis = plt.gca()
axis.set(xlim=(1.2, 1.50), ylim =(-0.7, -0.4))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("NBO charge transfer on O")

plt.plot(NBO_CO2['BH_bond'], NBO_CO2['O'], colors['CO2'], label="$Free$ $CO_{2}$")
plt.plot(NBO_AlH3['BH_bond'], NBO_AlH3['O'], colors['AlH3_CO2'], label="$LA = AlH_{3}$")
plt.plot(NBO_Me3N['BH_bond'], NBO_Me3N['O'], colors['NMe3_CO2'], label="$LB = Me_{3}N$")
plt.plot(NBO_NCAl['BH_bond'], NBO_NCAl['O'], colors['NCAl_CO2'], label="$FLP = N/Al$")

plt.plot(CO2['TS_bond'], -0.491, "+k", label="$Transition$ $State$") # CO2
plt.plot(AlH3_CO2['TS_bond'], -0.439, "+k") # AlH3
plt.plot(NMe3_CO2['TS_bond'], -0.513, "+k") # NMe3
plt.plot(NCAl_CO2['TS_bond'], -0.592, "+k") # NCAl

plt.legend(fontsize='small')
plt.savefig("data/NBO_O.png", dpi=300)

# %%
# NBO charge comparison on H Atom
axis = plt.gca()
axis.set(xlim=(1.2, 1.50), ylim =(-0.15, 0.25))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("NBO charge transfer on H")

plt.plot(NBO_CO2['BH_bond'], NBO_CO2['H'], colors['CO2'], label="$Free$ $CO_{2}$")
plt.plot(NBO_AlH3['BH_bond'], NBO_AlH3['H'], colors['AlH3_CO2'], label="$LA = AlH_{3}$")
plt.plot(NBO_Me3N['BH_bond'], NBO_Me3N['H'], colors['NMe3_CO2'], label="$LB = Me_{3}N$")
plt.plot(NBO_NCAl['BH_bond'], NBO_NCAl['H'], colors['NCAl_CO2'], label="$FLP = N/Al$")

plt.plot(CO2['TS_bond'], 0.021, "+k", label="$Transition$ $State$") # CO2
plt.plot(AlH3_CO2['TS_bond'], 0.000, "+k") # AlH3
plt.plot(NMe3_CO2['TS_bond'], 0.031, "+k") # NMe3
plt.plot(NCAl_CO2['TS_bond'], 0.028, "+k") # NCAl

plt.legend(fontsize='small')
plt.savefig("data/NBO_H.png", dpi=300)

# %%
# NBO charge comparison on B Atom
axis = plt.gca()
axis.set(xlim=(1.2, 1.50), ylim =(-0.15, 0.35))
plt.xlabel("$B-H$ Bond ($Å$)")
plt.ylabel("NBO charge transfer on B")

plt.plot(NBO_CO2['BH_bond'], NBO_CO2['B'], colors['CO2'], label="$Free$ $CO_{2}$")
plt.plot(NBO_AlH3['BH_bond'], NBO_AlH3['B'], colors['AlH3_CO2'], label="$LA = AlH_{3}$")
plt.plot(NBO_Me3N['BH_bond'], NBO_Me3N['B'], colors['NMe3_CO2'], label="$LB = Me_{3}N$")
plt.plot(NBO_NCAl['BH_bond'], NBO_NCAl['B'], colors['NCAl_CO2'], label="$FLP = N/Al$")

plt.plot(CO2['TS_bond'], 0.013, "+k", label="$Transition$ $State$") # CO2
plt.plot(AlH3_CO2['TS_bond'], 0.022, "+k") # AlH3
plt.plot(NMe3_CO2['TS_bond'], 0.022, "+k") # NMe3
plt.plot(NCAl_CO2['TS_bond'], 0.004, "+k") # NCAl

plt.legend(fontsize='small')
plt.savefig("data/NBO_B.png", dpi=300)
